# %%
import numpy as np
import pandas as pd
from sklearn import cross_validation
from sklearn import neighbors
from sklearn import grid_search
from sklearn import metrics
from sklearn import linear_model

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid", font_scale=1)
# %matplotlib inline

# Load data
df = pd.read_csv("src/db/analytics/test.csv")

df.drop(df.columns[0], axis=1, inplace=True)
# Check head
df.head()
# Out:
#                            track_id  year  total_curses  unique_words  \
# 0  10000maniacs<SEP>becausethenight  1994             1            80
# 1              10cc<SEP>imnotinlove  1975             0            74
# 2                  112<SEP>anywhere  1999             1           144
# 3                     112<SEP>cupid  1997             0            90
# 4        20fingers<SEP>shortdickman  1995            13            49
#
#    density  creativity
# 0      250    0.320000
# 1      255    0.290196
# 2      573    0.251309
# 3      379    0.237467
# 4      252    0.194444

# %%
df.describe()
# Out:
#               year  total_curses  unique_words      density   creativity
# count  2268.000000   2268.000000   2268.000000  2268.000000  2268.000000
# mean   1986.314374      1.194885    100.350088   333.400353     0.326532
# std      13.757443      5.354148     43.515813   170.109244     0.098267
# min    1961.000000      0.000000      5.000000    15.000000     0.054156
# 25%    1975.000000      0.000000     74.000000   218.750000     0.258922
# 50%    1987.000000      0.000000     91.000000   294.000000     0.315312
# 75%    1998.000000      0.000000    113.000000   398.000000     0.385043
# max    2010.000000     88.000000    400.000000  1288.000000     1.000000

# %%
# Get pair plot for data
sns.pairplot(df)

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbf848e36d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbf845ebf90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbf84640550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbf84625090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbf82d221d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbf82cefe90>]], dtype=object)
